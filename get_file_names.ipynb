# %%
import os

# %%
f = []
for (dirpath, dirnames, filenames) in os.walk("faces/"):
    f.extend(filenames)

# %%
f
# Out:
# ['.anonr',
#  'an2i_left_angry_open.pgm',
#  'an2i_left_angry_open_2.pgm',
#  'an2i_left_angry_open_4.pgm',
#  'an2i_left_angry_sunglasses.pgm',
#  'an2i_left_angry_sunglasses_2.pgm',
#  'an2i_left_angry_sunglasses_4.pgm',
#  'an2i_left_happy_open.pgm',
#  'an2i_left_happy_open_2.pgm',
#  'an2i_left_happy_open_4.pgm',
#  'an2i_left_happy_sunglasses.pgm',
#  'an2i_left_happy_sunglasses_2.pgm',
#  'an2i_left_happy_sunglasses_4.pgm',
#  'an2i_left_neutral_open.pgm',
#  'an2i_left_neutral_open_2.pgm',
#  'an2i_left_neutral_open_4.pgm',
#  'an2i_left_neutral_sunglasses.pgm',
#  'an2i_left_neutral_sunglasses_2.pgm',
#  'an2i_left_neutral_sunglasses_4.pgm',
#  'an2i_left_sad_open.pgm',
#  'an2i_left_sad_open_2.pgm',
#  'an2i_left_sad_open_4.pgm',
#  'an2i_left_sad_sunglasses.pgm',
#  'an2i_left_sad_sunglasses_2.pgm',
#  'an2i_left_sad_sunglasses_4.pgm',
#  'an2i_right_angry_open.pgm',
#  'an2i_right_angry_open_2.pgm',
#  'an2i_right_angry_open_4.pgm',
#  'an2i_right_angry_sunglasses.pgm',
# ...

# %%
pgm2 = []
for name in f:
    if name[-3:] == '.bad':
        pgm2.append('faces/' + name.split('_')[0] + '/' + name)

# %%
pgm2
# Out:
# []
